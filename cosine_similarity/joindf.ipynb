# %%
import pandas as pd

# %%
df1=pd.read_csv('output_manga.csv')
df2=pd.read_csv('output_manga2.csv')
df3=pd.read_csv('output_manga3.csv')

# %%
df1
# Out:
#                                 title  mal_id      type  chapters  volumes  \
# 0                             Berserk       2     Manga     380.0     41.0
# 1               Boku no Hero Academia   75989     Manga       NaN      NaN
# 2     Boruto: Naruto Next Generations   95210     Manga       NaN      NaN
# 3                         Break Blade    4608     Manga       NaN      NaN
# 4     Code Geass: Hangyaku no Lelouch    1528     Manga      40.0      8.0
# ...                               ...     ...       ...       ...      ...
# 2307                         Moon You  124471    Manhwa      68.0      4.0
# 2308          Pocket Monsters Horizon  104932     Manga      11.0      2.0
# 2309                             RWBY   93675     Manga      12.0      1.0
# 2310                         Sakamoto  131487  One-shot       1.0      NaN
# 2311                   Sennen no Yuki     156     Manga      18.0      4.0
#
# ...

# %%
manga=pd.concat([df1, df2,df3], ignore_index=True)

# %%
manga
# Out:
#                                                   title  mal_id   type  \
# 0                                               Berserk       2  Manga
# 1                                 Boku no Hero Academia   75989  Manga
# 2                       Boruto: Naruto Next Generations   95210  Manga
# 3                                           Break Blade    4608  Manga
# 4                       Code Geass: Hangyaku no Lelouch    1528  Manga
# ...                                                 ...     ...    ...
# 6498                                         Necromance  121456  Manga
# 6499                          Ninja Tensei Shinobi Kill  116574  Manga
# 6500  Nise Seiken Monogatari: Osananajimi no Seijo w...  125045  Manga
# 6501                                              Ogeha   96456  Manga
# 6502                                Ojousama no Shimobe  111136  Manga
#
#       chapters  volumes      status  \
# 0        380.0     41.0   On Hiatus
# 1          NaN      NaN  Publishing
# ...

# %%
manga.to_csv('mal_manga_df.csv', index=False)
